# %% [markdown]
# <a href="https://colab.research.google.com/github/jpastor1649/MetNumUN2024II/blob/main/Quantiacs/LabQuantiacs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **JOHN ALEJANDRO PASTOR SANDOVAL; METNUM2024-2**

# %% [markdown]
# #CONCURSO QUANTIACS
#
#
# **The Machine Learning technique**: Linear regression was replaced by Random Forest Regressor. Random Forest is chosen because it can capture relationships
# non-linear and interactions between characteristics, which are common in financial information. This can increase the accuracy
# of stock price predictions.
#
# **The market**: from NASDAQ to S&P 500.
#
# **The assets**: The assets that I selected to cover key sectors including technology, healthcare, energy, manufacturing, and real estate. They provide a balanced mix of stability from defensive markets and growth potential from innovative industries like biotechnology and renewable energy, making them suitable for diversified algorithmic trading strategies.
#
# **The variables**: I add variables like the **ATR (Average True Range)** which measures volatility, helping to define stop-loss levels. The **EMA (Exponential Moving Average) of ROC (Rate of Change)** smoothes fluctuations to identify market trends. The **CCI (Commodity Channel Index)** evaluates whether the price is at overbought or oversold levels by comparing the typical price with its moving average and standard deviation. Finally, the **Price Range** shows the difference between the daily high and low price, providing a simple measure of volatility.
#
# **The Targets** : the categorizations is: 1 when the price increases by more than 0.1%.
# 0 when the change is within ±0.1%.
# -1 when the price decreases by more than 0.1%.
# This categorization can be useful for analyzing price movements in financial markets, especially in the development of predictive models or trading strategies.
#
# **Liquidity** : we add to the weights the feature of liquidity to just work with assets that are not in bankrupt:

# %% [markdown]
# #THIS IS THE RESULT OF THE CHANGES MADE

# %% [markdown]
# **These are the new assets**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **These are the new variables**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Importance of features**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sharpe ratio before backtesting, strange value**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Sharpe Ratio with backtesting**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **STATISTICS OF STRATEGY**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
